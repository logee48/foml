# %% [markdown]
# <a href="https://colab.research.google.com/github/logee48/foml/blob/main/foml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd

df = pd.read_csv(r"/content/sample_data/california_housing_test.csv")
df.head(2)

# print(df.to_string())
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0

# %%
df['latitude'].value_counts()
#count no of occurences and total count
# Out:
# 34.02    35
# 34.06    33
# 34.05    32
# 34.07    31
# 34.11    31
#          ..
# 37.08     1
# 39.19     1
# 38.21     1
# 36.55     1
# 34.68     1
# Name: latitude, Length: 587, dtype: int64

# %%
df.latitude.unique()
#display unique elements
# Out:
# array([37.37, 34.26, 33.78, 33.82, 36.33, 36.51, 38.63, 35.48, 38.4 ,
#        34.08, 33.98, 35.85, 37.25, 32.97, 33.73, 33.81, 37.53, 38.69,
#        34.21, 38.01, 37.75, 38.68, 34.07, 37.79, 33.28, 34.16, 37.76,
#        33.99, 34.01, 33.91, 39.31, 34.55, 33.94, 34.  , 37.97, 33.92,
#        33.93, 34.23, 36.2 , 32.77, 34.15, 34.09, 34.13, 33.17, 37.44,
#        38.  , 37.7 , 35.97, 37.8 , 33.8 , 38.72, 37.33, 37.56, 37.23,
#        40.87, 32.73, 37.69, 33.86, 34.04, 37.36, 39.5 , 37.49, 37.35,
#        34.2 , 34.17, 37.99, 37.4 , 34.05, 34.25, 38.26, 37.68, 36.74,
#        41.01, 37.62, 37.98, 33.87, 37.84, 36.64, 36.77, 38.42, 38.87,
#        33.77, 34.02, 38.62, 32.8 , 36.54, 38.52, 34.27, 37.74, 40.77,
#        33.63, 34.1 , 32.81, 37.34, 33.02, 37.3 , 38.55, 36.61, 33.84,
#        37.73, 37.96, 34.03, 34.71, 36.75, 40.46, 36.95, 39.49, 32.75,
#        39.28, 32.72, 37.54, 37.6 , 33.15, 37.72, 33.64, 32.79, 33.62,
# ...

# %%
newone = df[df['latitude']==38.5]
print(newone)
#compare val
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1792    -121.53      38.5                17.0       3087.0           477.0
# 1896    -121.42      38.5                24.0       7740.0          1539.0
# 2816    -121.54      38.5                15.0       6093.0          1051.0
#
#       population  households  median_income  median_house_value
# 1792      1365.0       495.0         6.4667            216800.0
# 1896      4333.0      1397.0         3.0250             87900.0
# 2816      2415.0       997.0         4.2075            183600.0

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
df.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %%
test = df.isnull()
print(test)
# var = df[df['latitude']==True]
# print(var)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0         False     False               False        False           False
# 1         False     False               False        False           False
# 2         False     False               False        False           False
# 3         False     False               False        False           False
# 4         False     False               False        False           False
# ...         ...       ...                 ...          ...             ...
# 2995      False     False               False        False           False
# 2996      False     False               False        False           False
# 2997      False     False               False        False           False
# 2998      False     False               False        False           False
# 2999      False     False               False        False           False
#
#       population  households  median_income  median_house_value
# ...
